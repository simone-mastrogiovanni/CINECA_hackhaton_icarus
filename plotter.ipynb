# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
def pl(x, a):
    return x**a

# %%
data_cpu = np.genfromtxt('timing/CPU.txt')
data_gpu = np.genfromtxt('timing/GPU.txt')
data_gpu_jax = np.genfromtxt('timing/GPU_jax.txt')


# m_cpu,b_cpu = np.polyfit(np.log10(data_cpu[:,0]),np.log10(data_cpu[:,1]), 1)
# m_gpu,b_gpu = np.polyfit(np.log10(data_gpu[:,0]),np.log10(data_gpu[:,1]), 1)

# %%
plt.figure(figsize=(7.0,4.))
plt.scatter(data_gpu[:,0],data_gpu[:,1],label='M100 CUPY/GPU')
plt.scatter(data_gpu_jax[:,0],data_gpu_jax[:,1],label='M100 JAX/GPU')
plt.scatter(data_cpu[:,0],data_cpu[:,1],label='M100 CPU',marker='p',color='purple')
plt.yscale('log')
plt.xscale('log')
plt.ylabel(r'Likelihood computation [s]')
plt.xlabel(r'Number of samples')
plt.grid()
plt.legend()
plt.tight_layout()
